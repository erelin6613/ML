# %%
from sklearn.datasets.samples_generator import make_blobs
from sklearn.cluster import KMeans
from sklearn import preprocessing

X, y = make_blobs(n_samples=500, centers=3, n_features=2, random_state=0)
print(X)
print(y)
# Out:
# [[ 1.10318217  4.70577669]
#  [-1.93284574  3.64225077]
#  [-2.03442161  1.86600216]
#  [ 1.6164016   2.68683128]
#  [-0.96000973  4.49256592]
#  [ 0.94808785  4.7321192 ]
#  [ 0.33265168  2.08038418]
#  [-1.32893672  3.99981748]
#  [-1.29885069  3.11936221]
#  [ 1.72345841  3.11484237]
#  [-2.42430494  4.23035263]
#  [-1.54176172  3.7392882 ]
#  [-2.3858764   2.0189401 ]
#  [-0.44552798  2.28650627]
#  [-0.33963733  3.84220272]
#  [ 0.85810603  3.62360912]
#  [ 2.99831361 -1.84201351]
#  [ 3.13950603  5.64031528]
#  [-1.02885161  2.89169002]
#  [ 0.91464368  4.19648205]
#  [ 2.39417165  2.91870722]
#  [ 1.02533224  0.5477203 ]
#  [ 1.96933675  1.0919566 ]
#  [-2.31557327  4.01252064]
#  [ 1.35269561  3.20438654]
#  [-0.96289548  1.63332996]
#  [ 1.14650428  0.47334604]
#  [-0.5859864   3.32308634]
#  [ 0.10547293  3.72493766]
#  [-0.99796039  3.16403005]
#  [-0.80692028  1.81497605]
#  [ 2.20656076  5.50616718]
#  [ 0.06344785  5.42080362]
#  [-1.68290216  4.91010685]
# ...

# %%
import matplotlib.pyplot as plt

# %%
#X = preprocessing.scale(X)

# %%
y_means = KMeans(n_clusters = 3)

# %%
print(y_means)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
y_1 = y_means.fit(X)
centers = y_1.cluster_centers_
for i in range(len(X)):
    plt.scatter(-0.9, 4.5, c = 'g', s=150)
    plt.scatter(centers[:, 0], centers[:, 1], c='black', s=100, alpha=0.5)
    if y[i] == 0:
        plt.scatter(X[i][0], X[i][1], c = 'b')
    if y[i] == 1:
        plt.scatter(X[i][0], X[i][1], c = 'r')
    if y[i] == 2:
        plt.scatter(X[i][0], X[i][1], c = 'y')
plt.show()

# %%
y_1.score(X, y)
# Out:
# -881.7482774866189

# %%
t = y_1.predict([[-0.9, 4.5]])
print(t)
# Out:
# [0]

# %%
plt.scatter(-0.9, 4.5, c = 'g')
